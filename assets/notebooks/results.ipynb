# %% [markdown]
# # RQ1.1
#
# ||||| **Line-level**   || **Token-level**       |
# |:--------:|-------------------|-------------------|----------------|:------------:|:--------------:|:--------------:|
# | **Rank** | **Model**         | **Team name**     | **Date**       | **EM**       | **ES**         | **Acc**        |
# | **1**    | PyCoder-Hard      | Monash University | 2022-10-13     | **43.91**    | 71.74          | **76.93**      |
# | **2**    | UniXcoder         | Guo ea.           | 2022 (publish) | 43.12        | **72.00**      | -              |
# | **3**    | CodeGPT-adapt     | CodeXGLUE Team    | 2020-08-30     | 42.37        | 71.59          | 76.60          |
# | **4**    | CodeGPT           | CodeXGLUE Team    | 2020-08-30     | 42.18        | 71.23          | 76.58          |
# | **5**    | GPT-2             | CodeXGLUE Team    | 2020-08-30     | 41.73        | 70.60          | 75.90          |
# | **6**    | Transformer (12L) | CodeXGLUE Team    | 2020-08-30     | 38.51        | 69.01          | 74.48          |
# | **7**    | LSTM + BPE        | CodeXGLUE Team    | 2020-08-30     | 23.77        | 56.26          | 61.94          |

# %% [markdown]
# ## RQ1.2
#
# || **Line-level**   |||||| **Token-level**       |
# |:-------------:|:------------:|:--------------:|:--------------:|:----------------:|:----------------:|:-----------------:|:--------------:|
# | **Model**        | **EM**    | **ES**         | **MRR**        | **BLEU-4**       | **METEOR**       | **ROUGE-L**       | **Acc**        |
# | **PyCoder-Hard** | **43.37** | **73.20**      | **48.82**      | **46.03**        | **40.42**        | **59.97**         | **77.12**      |
# | **UniXCoder** | 40.68        | 71.99          | 45.85          | 43.31            | 39.26            | 58.36             | -              |
# | **CodeGPT**   | 40.03        | 70.61          | 46.64          | 42.12            | 38.53            | 56.96             | 75.69          |
# | **TravTrans** | -            | -              | -              | -                | -                | -                 | 75.50          |
# | **GPT-2**     | 37.64        | 68.44          | 43.85          | 39.23            | 36.89            | 54.32             | 73.89          |
# | **PMN**       | -            | -              | -              | -                | -                | -                 | 69.02          |

# %% [markdown]
# ## RQ2
# || **Line-level**   |||||| **Token-level**       |
# |------------------|:--------------:|:---------------:|:--------------:|:--------------:|:--------------:|:--------------:|:---------------|
# | **Model**        | **EM**       | **ES**         | **MRR**        | **BLEU-4**     | **METEOR**     | **ROUGE-L**    | **Acc**        |
# | **PyCoder-Hard** | **42.83** | **72.82** | 48.42          | **45.52** | **40.05** | **59.40** | **77.00** |
# | **PyCoder-IFN**  | 42.04        | 71.92          | **48.54** | 44.18          | 39.40          | 58.41          | 76.52          |
# | **PyCoder-Soft** | 38.29        | 69.11          | 44.66          | 39.85          | 37.36          | 55.24          | 74.77          |

# %% [markdown]
# ## RQ3
# || **Line-level**   |||||| **Token-level**       |
# |:-------------:|:------------:|:--------------:|:--------------:|:----------------:|:----------------:|:-----------------:|:--------------:|
# | **Type:Code** | **EM**       | **ES**         | **MRR**        | **BLEU-4**       | **METEOR**       | **ROUGE-L**       | **Acc**        |
# | **No Weight** | 42.83        | 72.82          | 48.42          | 45.52            | 40.05            | 59.40             | 77.00          |
# | **1 : 9**     | **43.37**    | **73.20**      | 48.82          | 46.03            | **40.42**        | **59.97**         | **77.12**      |
# | **2 : 8**     | 43.08        | 73.01          | 48.73          | **46.12**        | 40.37            | 59.69             | **77.12**      |
# | **3 : 7**     | 42.95        | 72.94          | 48.56          | 45.80            | 40.27            | 59.57             | 77.10          |
# | **4 : 6**     | 42.84        | 73.03          | 48.55          | 45.75            | 40.31            | 59.68             | 77.05          |
# | **5 : 5**     | 42.94        | 72.69          | **49.53**      | 45.39            | 39.99            | 59.42             | 76.99          |
# | **6 : 4**     | 42.37        | 72.29          | 49.10          | 44.77            | 39.78            | 59.09             | 76.88          |
# | **7 : 3**     | 42.28        | 72.27          | 47.82          | 44.83            | 39.68            | 58.89             | 76.70          |
# | **8 : 2**     | 41.19        | 71.68          | 46.76          | 43.79            | 39.25            | 58.07             | 76.23          |
# | **9 : 1**     | 39.77        | 70.52          | 46.34          | 41.80            | 38.34            | 56.66             | 75.45          |

# %% [markdown]
# ## RQ4
#
# ||| **Line-level**   |||||
# |:---------------:|:-------------------------------:|:--------------:|:---------------------:|:---------------------:|:---------------------:|:---------------------:|
# | **Library**     | **Method**                      | **EM**         | **ES**                | **BLEU-4**            | **METEOR**            | **ROUGE-L**     |
# | **CodeXGLUE**   | Beam Search ($b$=5)             | **43.37**      | 73.20                 | 46.03                 | 40.42                 | 59.97                 |
# | ****            | Greedy                          | 41.47          | **73.95**             | **47.83**             | **42.34**             | **60.46**        |
# | **HuggingFace** | Beam Search ($b$=5)             | **41.52**      | 72.85                 | 46.8                  | 42.04                 | 59.62                 |
# | ****            | Greedy                          | 41.48          | 73.96                 | 47.83                 | **42.35**             | 60.47                 |
# | ****            | Sampling                        | 33.80 (0.16)   | 68.72 (0.11)          | 40.80 (0.18)          | 39.32 (0.08)          | 54.18 (0.16)          |
# | ****            | Sampling with Temp ($temp$=0.1) | 41.38 (0.10)   | **73.98 (0.03)**      | **47.91 (0.07)**      | 42.31 (0.04)          | **60.48 (0.04)** |
# | ****            | Top-K Sampling ($k$=3)          | 35.34 (0.16)   | 70.43 (0.11)          | 43.01 (0.12)          | 40.15 (0.09)          | 56.43 (0.11)          |
# | ****            | Top-P Sampling ($p$=0.1)        | 41.48 (0.01)   | 73.95 (0.01)          | 47.82 (0.03)          | **42.35 (0.01)**      | 60.46 (0.01)          |
